# %%
# Add the Pandas dependency.
import pandas as pd

# %%
# Files to load
traffick_data = "human_traffick_sample_dataset.csv"

# %%
traffick_data_df = pd.read_csv(traffick_data)
traffick_data_df.head()
# Out:
#    registration_year       datasource  gender age_range majority_status  \
# 0               2017  Case Management  Female      0--8           Minor
# 1               2017  Case Management  Female      0--8           Minor
# 2               2017  Case Management  Female    18--20           Adult
# 3               2017  Case Management  Female    18--20           Adult
# 4               2017  Case Management  Female    21--23           Adult
#
#   majority_status_at_exploit majority_entry citizenship  \
# 0                      Minor            -99         -99
# 1                      Minor            -99         -99
# 2                      Adult            -99          KH
# 3                        -99            -99          UA
# 4                      Minor            -99          VN
#
#   country_of_exploitation  control_financial  control_threats  \
# 0                      KH                -99              -99
# 1                      KH                -99                1
# 2                      CN                -99                1
# 3                      UA                -99              -99
# 4                      VN                -99                1
#
#    control_physical  control_limit_necessities  control_other  labor  \
# 0                 1                        -99              1      0
# 1                 1                        -99              1    -99
# 2                 1                        -99            -99    -99
# 3               -99                        -99              1    -99
# 4               -99                        -99            -99      3
#
#    victim_purpose  trafficker_relationship
# 0             -99                      -99
# 1               6                        4
# 2               3                        3
# 3             -99                        4
# 4               6                      -99

# %%
for col_name in traffick_data_df.columns: 
    print(col_name)
# Out:
# registration_year
# datasource
# gender
# age_range
# majority_status
# majority_status_at_exploit
# majority_entry
# citizenship
# country_of_exploitation
# control_financial
# control_threats
# control_physical
# control_limit_necessities
# control_other
# labor
# victim_purpose
# trafficker_relationship
