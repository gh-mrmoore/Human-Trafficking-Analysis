# %%
# Add the Pandas dependency.
import pandas as pd
import numpy as np

# %%
traffick_data='Resources\human_traffick_sample_dataset_mrm.csv'

# %%
traffick_data_df = pd.read_csv(traffick_data)
traffick_data_df.head()
# Out:
#    registration_year       datasource  gender age_range majority_status  \
# 0               2017  Case Management  Female      0--8           Minor
# 1               2017  Case Management  Female      0--8           Minor
# 2               2017  Case Management  Female    18--20           Adult
# 3               2017  Case Management  Female    18--20           Adult
# 4               2017  Case Management  Female    21--23           Adult
#
#   majority_status_at_exploit majority_entry citizenship  \
# 0                      Minor            -99         -99
# 1                      Minor            -99         -99
# 2                      Adult            -99          KH
# 3                        -99            -99          UA
# 4                      Minor            -99          VN
#
#   country_of_exploitation  control_financial  control_threats  \
# 0                      KH                -99              -99
# 1                      KH                -99                1
# ...

# %%
country_count = traffick_data_df['country_of_exploitation'].value_counts()
country_count

# pd.value_counts(traffick_data_df['country_of_exploitation']).values

# group = traffick_data_df.groupby('country_of_exploitation')
# group.count()

# group[['country_of_exploitation', 'gender' ]]


# df1=pd.DataFrame(group.count())
# df1

# df1[['country_of_exploitation', 'registration_year']]
# Out:
# KH    40
# MY    34
# US    30
# UA    26
# CN    26
# IN    22
# SA    14
# BD    12
# VN     2
# MD     2
# Name: country_of_exploitation, dtype: int64

# %%
# Add the cout
traffick_data_df[['country_of_exploitation',]].value_counts()
# pd.value_counts(traffick_data_df['country_of_exploitation'])

# df1=group[['country_of_exploitation', 'datasource']]

# df1.set_index['country_of_exploitation', 'datasource']
# Out:
# country_of_exploitation
# KH                         40
# MY                         34
# US                         30
# CN                         26
# UA                         26
# IN                         22
# SA                         14
# BD                         12
# MD                          2
# VN                          2
# dtype: int64

# %%
df = pd.DataFrame(country_count)

# %%
df.head()
# Out:
#     country_of_exploitation
# KH                       40
# MY                       34
# US                       30
# UA                       26
# CN                       26

# %%
df.columns
# Out:
# Index(['country_of_exploitation'], dtype='object')

# %%
df.reset_index()
# Out:
#   index  country_of_exploitation
# 0    KH                       40
# 1    MY                       34
# 2    US                       30
# 3    UA                       26
# 4    CN                       26
# 5    IN                       22
# 6    SA                       14
# 7    BD                       12
# 8    VN                        2
# 9    MD                        2
