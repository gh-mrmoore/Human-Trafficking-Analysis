# %% [markdown]
# ## Question
# What impact does a country's economic status (as measured by GDP and other factors) affect the number of human trafficking cases reported in that country?
#
# ### Model
# Based on a known dataset, can linear regression be used to determine any relationship between the number of victims of human trafficking each year in a given country and that country's population?
#
# ### Output
# We hope to find a line where as GDP, unemployment and other factors change, the number of human trafficking cases may be predicted. If the number of cases can be predicted/modeled, one of two outcomes may be possible:
# * Examine existing cases for possible under-reporting and encouraging law enforcement to act more pro-actively.
# * Allow leadership in given countries the opportunity to curb trafficking by improving economic conditions within their respective country.

# %%
# Import Dependencies
import os
import pandas as pd
import numpy as np

from sqlalchemy import create_engine
from config import conn

# from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# %%
# Get trafficking data
trafficking_df = pd.read_sql_table("Trafficking_Cleaned", conn)
trafficking_df
# Out:
#        yearOfRegistration       Datasource  gender citizenship  \
# 0                    2012  Case Management  Female          LK
# 1                    2012  Case Management  Female          LK
# 2                    2012  Case Management  Female          LK
# 3                    2012  Case Management  Female          LK
# 4                    2012  Case Management  Female          LK
# ...                   ...              ...     ...         ...
# 14294                2018          Hotline    Male          US
# 14295                2018          Hotline    Male          US
# 14296                2018          Hotline    Male          US
# 14297                2018          Hotline    Male          US
# 14298                2018          Hotline    Male          US
#
#        isForcedLabour ControlCategory RecruiterCategory          ExploitType  \
# 0                   1         Threats             Other         Forced Labor
# 1                   1       Financial             Other         Forced Labor
# 2                   1         Threats             Other         Forced Labor
# 3                   1       Financial             Other         Forced Labor
# 4                   1       Financial             Other         Forced Labor
# ...               ...             ...               ...                  ...
# 14294               0         Threats   Family/Relative  Sexual Exploitation
# 14295               0         Threats   Family/Relative  Sexual Exploitation
# 14296               0         Threats   Family/Relative  Sexual Exploitation
# 14297               0           Other   Family/Relative  Sexual Exploitation
# 14298               0         Threats   Family/Relative  Sexual Exploitation
#
#           Labor_Type ageCategories
# 0      Domestic Work     Age 30-38
# 1      Domestic Work     Age 30-38
# 2      Domestic Work     Age 30-38
# 3      Domestic Work     Age 30-38
# 4      Domestic Work     Age 30-38
# ...              ...           ...
# 14294        Unknown      Age 9-17
# 14295        Unknown      Age 9-17
# 14296        Unknown      Age 9-17
# 14297        Unknown      Age 9-17
# 14298        Unknown      Age 9-17
#
# [14299 rows x 10 columns]

# %%
# Get total case counts for each country by year
cases_by_year = trafficking_df.groupby(["citizenship", "yearOfRegistration"]).size().reset_index(name="case_counts")
cases_by_year
# Out:
#    citizenship  yearOfRegistration  case_counts
# 0            0                2015          811
# 1            0                2016         1860
# 2            0                2017         2448
# 3            0                2018         3234
# 4           AF                2013            3
# 5           AF                2014            1
# 6           BY                2015           90
# 7           BY                2016          112
# 8           BY                2017           30
# 9           CN                2017           11
# 10          CN                2018           12
# 11          ER                2014            1
# 12          HT                2012           89
# 13          ID                2014            1
# 14          ID                2015            6
# 15          ID                2016           28
# 16          ID                2017           34
# 17          KE                2017           29
# 18          KG                2014           71
# 19          KG                2015           66
# 20          KG                2016           20
# 21          KH                2015           20
# 22          KH                2016           31
# 23          KH                2017           74
# 24          KH                2018           14
# 25          KR                2016           12
# 26          LK                2012           31
# 27          LK                2013           42
# 28          MM                2013           20
# 29          MM                2014            3
# 30          MM                2015          102
# 31          MM                2016           35
# 32          MM                2018           26
# 33          MX                2017           19
# 34          NG                2015           98
# 35          NP                2015           27
# 36          PH                2015           25
# 37          PH                2016           13
# 38          TH                2016           53
# 39          UA                2013          172
# 40          UA                2014           69
# 41          UA                2015          332
# 42          UA                2016          320
# 43          UA                2017          123
# 44          UG                2014           66
# 45          US                2015          631
# 46          US                2016         1227
# 47          US                2017         1064
# 48          US                2018          668
# 49          UZ                2015           10
# 50          UZ                2017           15

# %%
# Get country data
countries_df = pd.read_sql_table("Country_Codes", conn)
countries_df
# Out:
#                   country_name country_iso2 country_iso3 country_un_code
# 0                  Afghanistan           AF          AFG               4
# 1                Aland Islands           AX          ALA             248
# 2                      Albania           AL          ALB               8
# 3                      Algeria           DZ          DZA              12
# 4               American Samoa           AS          ASM              16
# ..                         ...          ...          ...             ...
# 242  Wallis and Futuna Islands           WF          WLF             876
# 243             Western Sahara           EH          ESH             732
# 244                      Yemen           YE          YEM             887
# 245                     Zambia           ZM          ZMB             894
# 246                   Zimbabwe           ZW          ZWE             716
#
# [247 rows x 4 columns]

# %%
# Merge our country code cross-reference to our aggregated cases per country per year
trafficking_x_countries = cases_by_year.merge(countries_df, how='left', left_on='citizenship', right_on='country_iso2')
trafficking_x_countries
# Out:
#    citizenship  yearOfRegistration  case_counts              country_name  \
# 0            0                2015          811                       NaN
# 1            0                2016         1860                       NaN
# 2            0                2017         2448                       NaN
# 3            0                2018         3234                       NaN
# 4           AF                2013            3               Afghanistan
# 5           AF                2014            1               Afghanistan
# 6           BY                2015           90                   Belarus
# 7           BY                2016          112                   Belarus
# 8           BY                2017           30                   Belarus
# 9           CN                2017           11                     China
# 10          CN                2018           12                     China
# 11          ER                2014            1                   Eritrea
# 12          HT                2012           89                     Haiti
# 13          ID                2014            1                 Indonesia
# 14          ID                2015            6                 Indonesia
# 15          ID                2016           28                 Indonesia
# 16          ID                2017           34                 Indonesia
# 17          KE                2017           29                     Kenya
# 18          KG                2014           71                Kyrgyzstan
# 19          KG                2015           66                Kyrgyzstan
# 20          KG                2016           20                Kyrgyzstan
# 21          KH                2015           20                  Cambodia
# 22          KH                2016           31                  Cambodia
# 23          KH                2017           74                  Cambodia
# 24          KH                2018           14                  Cambodia
# 25          KR                2016           12             Korea (South)
# 26          LK                2012           31                 Sri Lanka
# 27          LK                2013           42                 Sri Lanka
# 28          MM                2013           20                   Myanmar
# 29          MM                2014            3                   Myanmar
# 30          MM                2015          102                   Myanmar
# 31          MM                2016           35                   Myanmar
# 32          MM                2018           26                   Myanmar
# 33          MX                2017           19                    Mexico
# 34          NG                2015           98                   Nigeria
# 35          NP                2015           27                     Nepal
# 36          PH                2015           25               Philippines
# 37          PH                2016           13               Philippines
# 38          TH                2016           53                  Thailand
# 39          UA                2013          172                   Ukraine
# 40          UA                2014           69                   Ukraine
# 41          UA                2015          332                   Ukraine
# 42          UA                2016          320                   Ukraine
# 43          UA                2017          123                   Ukraine
# 44          UG                2014           66                    Uganda
# 45          US                2015          631  United States of America
# 46          US                2016         1227  United States of America
# 47          US                2017         1064  United States of America
# 48          US                2018          668  United States of America
# 49          UZ                2015           10                Uzbekistan
# 50          UZ                2017           15                Uzbekistan
#
#    country_iso2 country_iso3 country_un_code
# 0           NaN          NaN             NaN
# 1           NaN          NaN             NaN
# 2           NaN          NaN             NaN
# 3           NaN          NaN             NaN
# 4            AF          AFG               4
# 5            AF          AFG               4
# 6            BY          BLR             112
# 7            BY          BLR             112
# 8            BY          BLR             112
# 9            CN          CHN             156
# 10           CN          CHN             156
# 11           ER          ERI             232
# 12           HT          HTI             332
# 13           ID          IDN             360
# 14           ID          IDN             360
# 15           ID          IDN             360
# 16           ID          IDN             360
# 17           KE          KEN             404
# 18           KG          KGZ             417
# 19           KG          KGZ             417
# 20           KG          KGZ             417
# 21           KH          KHM             116
# 22           KH          KHM             116
# 23           KH          KHM             116
# 24           KH          KHM             116
# 25           KR          KOR             410
# 26           LK          LKA             144
# 27           LK          LKA             144
# 28           MM          MMR             104
# 29           MM          MMR             104
# 30           MM          MMR             104
# 31           MM          MMR             104
# 32           MM          MMR             104
# 33           MX          MEX             484
# 34           NG          NGA             566
# 35           NP          NPL             524
# 36           PH          PHL             608
# 37           PH          PHL             608
# 38           TH          THA             764
# 39           UA          UKR             804
# 40           UA          UKR             804
# 41           UA          UKR             804
# 42           UA          UKR             804
# 43           UA          UKR             804
# 44           UG          UGA             800
# 45           US          USA             840
# 46           US          USA             840
# 47           US          USA             840
# 48           US          USA             840
# 49           UZ          UZB             860
# 50           UZ          UZB             860

# %%
# Replace the `0` placeholder for unknowns with null/NaN values.
trafficking_x_countries["citizenship"].replace({'0': np.nan}, inplace=True)
trafficking_x_countries.dropna(inplace=True)
trafficking_x_countries
# Out:
#    citizenship  yearOfRegistration  case_counts              country_name  \
# 4           AF                2013            3               Afghanistan
# 5           AF                2014            1               Afghanistan
# 6           BY                2015           90                   Belarus
# 7           BY                2016          112                   Belarus
# 8           BY                2017           30                   Belarus
# 9           CN                2017           11                     China
# 10          CN                2018           12                     China
# 11          ER                2014            1                   Eritrea
# 12          HT                2012           89                     Haiti
# 13          ID                2014            1                 Indonesia
# 14          ID                2015            6                 Indonesia
# 15          ID                2016           28                 Indonesia
# 16          ID                2017           34                 Indonesia
# 17          KE                2017           29                     Kenya
# 18          KG                2014           71                Kyrgyzstan
# 19          KG                2015           66                Kyrgyzstan
# 20          KG                2016           20                Kyrgyzstan
# 21          KH                2015           20                  Cambodia
# 22          KH                2016           31                  Cambodia
# 23          KH                2017           74                  Cambodia
# 24          KH                2018           14                  Cambodia
# 25          KR                2016           12             Korea (South)
# 26          LK                2012           31                 Sri Lanka
# 27          LK                2013           42                 Sri Lanka
# 28          MM                2013           20                   Myanmar
# 29          MM                2014            3                   Myanmar
# 30          MM                2015          102                   Myanmar
# 31          MM                2016           35                   Myanmar
# 32          MM                2018           26                   Myanmar
# 33          MX                2017           19                    Mexico
# 34          NG                2015           98                   Nigeria
# 35          NP                2015           27                     Nepal
# 36          PH                2015           25               Philippines
# 37          PH                2016           13               Philippines
# 38          TH                2016           53                  Thailand
# 39          UA                2013          172                   Ukraine
# 40          UA                2014           69                   Ukraine
# 41          UA                2015          332                   Ukraine
# 42          UA                2016          320                   Ukraine
# 43          UA                2017          123                   Ukraine
# 44          UG                2014           66                    Uganda
# 45          US                2015          631  United States of America
# 46          US                2016         1227  United States of America
# 47          US                2017         1064  United States of America
# 48          US                2018          668  United States of America
# 49          UZ                2015           10                Uzbekistan
# 50          UZ                2017           15                Uzbekistan
#
#    country_iso2 country_iso3 country_un_code
# 4            AF          AFG               4
# 5            AF          AFG               4
# 6            BY          BLR             112
# 7            BY          BLR             112
# 8            BY          BLR             112
# 9            CN          CHN             156
# 10           CN          CHN             156
# 11           ER          ERI             232
# 12           HT          HTI             332
# 13           ID          IDN             360
# 14           ID          IDN             360
# 15           ID          IDN             360
# 16           ID          IDN             360
# 17           KE          KEN             404
# 18           KG          KGZ             417
# 19           KG          KGZ             417
# 20           KG          KGZ             417
# 21           KH          KHM             116
# 22           KH          KHM             116
# 23           KH          KHM             116
# 24           KH          KHM             116
# 25           KR          KOR             410
# 26           LK          LKA             144
# 27           LK          LKA             144
# 28           MM          MMR             104
# 29           MM          MMR             104
# 30           MM          MMR             104
# 31           MM          MMR             104
# 32           MM          MMR             104
# 33           MX          MEX             484
# 34           NG          NGA             566
# 35           NP          NPL             524
# 36           PH          PHL             608
# 37           PH          PHL             608
# 38           TH          THA             764
# 39           UA          UKR             804
# 40           UA          UKR             804
# 41           UA          UKR             804
# 42           UA          UKR             804
# 43           UA          UKR             804
# 44           UG          UGA             800
# 45           US          USA             840
# 46           US          USA             840
# 47           US          USA             840
# 48           US          USA             840
# 49           UZ          UZB             860
# 50           UZ          UZB             860

# %%
# Get the population data from our database, convert to DataFrame and merge on to our aggregated data.
gdp_df = pd.read_sql_table("WEO_Population", conn, index_col=["ISO"])

year_popn = []
for row in trafficking_x_countries.iterrows():
    year_popn.append(gdp_df.loc[row[1]['country_iso3'], str(row[1]['yearOfRegistration'])])

# Add our results to our cumulative DataFrame
trafficking_x_countries['Popn'] = year_popn
trafficking_x_countries
# Out:
#    citizenship  yearOfRegistration  case_counts              country_name  \
# 4           AF                2013            3               Afghanistan
# 5           AF                2014            1               Afghanistan
# 6           BY                2015           90                   Belarus
# 7           BY                2016          112                   Belarus
# 8           BY                2017           30                   Belarus
# 9           CN                2017           11                     China
# 10          CN                2018           12                     China
# 11          ER                2014            1                   Eritrea
# 12          HT                2012           89                     Haiti
# 13          ID                2014            1                 Indonesia
# 14          ID                2015            6                 Indonesia
# 15          ID                2016           28                 Indonesia
# 16          ID                2017           34                 Indonesia
# 17          KE                2017           29                     Kenya
# 18          KG                2014           71                Kyrgyzstan
# 19          KG                2015           66                Kyrgyzstan
# 20          KG                2016           20                Kyrgyzstan
# 21          KH                2015           20                  Cambodia
# 22          KH                2016           31                  Cambodia
# 23          KH                2017           74                  Cambodia
# 24          KH                2018           14                  Cambodia
# 25          KR                2016           12             Korea (South)
# 26          LK                2012           31                 Sri Lanka
# 27          LK                2013           42                 Sri Lanka
# 28          MM                2013           20                   Myanmar
# 29          MM                2014            3                   Myanmar
# 30          MM                2015          102                   Myanmar
# 31          MM                2016           35                   Myanmar
# 32          MM                2018           26                   Myanmar
# 33          MX                2017           19                    Mexico
# 34          NG                2015           98                   Nigeria
# 35          NP                2015           27                     Nepal
# 36          PH                2015           25               Philippines
# 37          PH                2016           13               Philippines
# 38          TH                2016           53                  Thailand
# 39          UA                2013          172                   Ukraine
# 40          UA                2014           69                   Ukraine
# 41          UA                2015          332                   Ukraine
# 42          UA                2016          320                   Ukraine
# 43          UA                2017          123                   Ukraine
# 44          UG                2014           66                    Uganda
# 45          US                2015          631  United States of America
# 46          US                2016         1227  United States of America
# 47          US                2017         1064  United States of America
# 48          US                2018          668  United States of America
# 49          UZ                2015           10                Uzbekistan
# 50          UZ                2017           15                Uzbekistan
#
#    country_iso2 country_iso3 country_un_code      Popn
# 4            AF          AFG               4    26.736
# 5            AF          AFG               4    27.601
# 6            BY          BLR             112     9.481
# 7            BY          BLR             112     9.498
# 8            BY          BLR             112     9.505
# 9            CN          CHN             156  1390.080
# 10           CN          CHN             156  1395.380
# 11           ER          ERI             232     3.311
# 12           HT          HTI             332    10.251
# 13           ID          IDN             360   252.165
# 14           ID          IDN             360   255.588
# 15           ID          IDN             360   258.497
# 16           ID          IDN             360   261.356
# 17           KE          KEN             404    45.400
# 18           KG          KGZ             417     5.777
# 19           KG          KGZ             417     5.895
# 20           KG          KGZ             417     6.019
# 21           KH          KHM             116    15.026
# 22           KH          KHM             116    15.181
# 23           KH          KHM             116    15.336
# 24           KH          KHM             116    15.491
# 25           KR          KOR             410    51.218
# 26           LK          LKA             144    20.425
# 27           LK          LKA             144    20.585
# 28           MM          MMR             104    50.324
# 29           MM          MMR             104    50.758
# 30           MM          MMR             104    51.199
# 31           MM          MMR             104    51.633
# 32           MM          MMR             104    52.449
# 33           MX          MEX             484   124.042
# 34           NG          NGA             566   181.137
# 35           NP          NPL             524    27.015
# 36           PH          PHL             608   100.830
# 37           PH          PHL             608   102.530
# 38           TH          THA             764    68.971
# 39           UA          UKR             804    45.246
# 40           UA          UKR             804    42.760
# 41           UA          UKR             804    42.591
# 42           UA          UKR             804    42.415
# 43           UA          UKR             804    42.217
# 44           UG          UGA             800    34.477
# 45           US          USA             840   320.823
# 46           US          USA             840   323.095
# 47           US          USA             840   325.143
# 48           US          USA             840   326.882
# 49           UZ          UZB             860    31.023
# 50           UZ          UZB             860    32.121

# %%
# Split to our 'X' and 'y' inputs.
y = trafficking_x_countries['case_counts']
X = trafficking_x_countries[['Popn']]

# %%
# Make a quick plot of our data
plt.scatter(X, y)
plt.show()

# %%
# Create our training and testing splits
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=52)

# %%
# Create and train regression model
popn_model = LinearRegression()

popn_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Create some predictions based on our X-test set
popn_predictions = popn_model.predict(X_test)
popn_predictions
# Out:
# array([114.7456796 , 172.39778828, 124.54810846, 443.99942929,
#        114.92457511, 188.709353  , 124.6573939 , 124.44500002,
#        119.04653684, 118.84103269, 124.65287994, 141.95870459])

# %%
# Chart our data and prediction
plt.scatter(X, y)
plt.title("Case Count (Per Country Per Year) vs. Population")
plt.plot(X_test, popn_predictions, color='red')
plt.savefig("fig_xx_cases_v_population", transparent=True)
plt.show()
