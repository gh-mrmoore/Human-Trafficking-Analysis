# %%
import os
import pandas as pd

# %%
# Import WEO dataset
weo_df = pd.read_excel("WEOApr2021all.xlsx", header=0)
weo_df.head()
# Out:
#   WEO Country Code  ISO WEO Subject Code      Country  \
# 0              512  AFG           NGDP_R  Afghanistan
# 1              512  AFG        NGDP_RPCH  Afghanistan
# 2              512  AFG             NGDP  Afghanistan
# 3              512  AFG            NGDPD  Afghanistan
# 4              512  AFG           PPPGDP  Afghanistan
#
#                         Subject Descriptor  \
# 0  Gross domestic product, constant prices
# 1  Gross domestic product, constant prices
# 2   Gross domestic product, current prices
# 3   Gross domestic product, current prices
# 4   Gross domestic product, current prices
#
#                                        Subject Notes  \
# 0  Expressed in billions of national currency uni...
# 1  Annual percentages of constant price GDP are y...
# 2  Expressed in billions of national currency uni...
# 3  Values are based upon GDP in national currency...
# 4  These data form the basis for the country weig...
#
# ...

# %%
# View columns
weo_df.columns
# Out:
# Index([             'WEO Country Code',                           'ISO',
#                     'WEO Subject Code',                       'Country',
#                   'Subject Descriptor',                 'Subject Notes',
#                                'Units',                         'Scale',
#        'Country/Series-specific Notes',                            1980,
#                                   1981,                            1982,
#                                   1983,                            1984,
#                                   1985,                            1986,
#                                   1987,                            1988,
#                                   1989,                            1990,
#                                   1991,                            1992,
#                                   1993,                            1994,
#                                   1995,                            1996,
# ...

# %%
# Drop unnecessary columns
weo_df.drop(["WEO Country Code", "Subject Descriptor", "Subject Notes", "Units", "Scale", 
             "Country/Series-specific Notes", 1980, 1981, 1982, 1983, 1984,
            1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996,
            1997, 1998, 1999, 2000, 2001, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, "Estimates Start After"], axis=1, inplace=True)
weo_df.head()
# Out:
#    ISO WEO Subject Code      Country     2002     2003     2004     2005  \
# 0  AFG           NGDP_R  Afghanistan  453.484  492.903  496.209   554.91
# 1  AFG        NGDP_RPCH  Afghanistan      NaN    8.692    0.671    11.83
# 2  AFG             NGDP  Afghanistan  178.756  220.013   246.21  304.926
# 3  AFG            NGDPD  Afghanistan    4.367    4.553    5.146    6.167
# 4  AFG           PPPGDP  Afghanistan   19.677   21.784   22.521   25.969
#
#       2006     2007     2008     2009     2010     2011     2012     2013  \
# 0  584.658   662.65  688.247  829.924  899.956  958.266  1092.12  1154.18
# 1    5.361    13.34    3.863   20.585    8.438    6.479   13.968    5.683
# 2  345.817  427.495  517.509  607.227  711.759  836.222  1033.59  1116.83
# 3    6.925    8.556   10.297   12.066   15.325    17.89   20.293    20.17
# 4    28.19   32.808   34.739   42.209   46.304   50.334   59.945   63.784
#
#       2014     2015     2016     2017     2018
# ...

# %% [markdown]
# # Create CSV for GDP

# %%
# Retreive all rows where WEO Subject Code is NGDPDPC for GDP
gdp_df = weo_df[weo_df['WEO Subject Code'] == "NGDPDPC"]
gdp_df.head()
# Out:
#      ISO WEO Subject Code              Country      2002     2003      2004  \
# 9    AFG          NGDPDPC          Afghanistan   233.433  233.755   254.259
# 54   ALB          NGDPDPC              Albania   1425.13  1846.12   2373.58
# 99   DZA          NGDPDPC              Algeria   1806.86  2128.39   2636.31
# 144  AGO          NGDPDPC               Angola    841.42  951.969   1222.04
# 189  ATG          NGDPDPC  Antigua and Barbuda  10482.01  10892.4  11581.32
#
#          2005     2006      2007      2008     2009      2010      2011  \
# 9     294.396  320.674   381.502   447.746  511.374    631.49     714.7
# 54    2673.77  2972.75   3595.05   4370.56  4114.09   4097.83   4439.89
# 99    3141.03  3508.96   3986.56    4943.5  3886.06   4480.72   5453.89
# 144   1862.42  2561.86   3099.09   4081.69   3146.8   3641.44   4716.25
# 189  12736.24  14262.1  15992.74  16510.08  14612.9  13564.68  13295.36
#
#          2012      2013      2014      2015      2016      2017      2018
# ...

# %%
# Save DF to CSV
gdp_df.to_csv('WEO_GDP.csv', index = False)

# %% [markdown]
# # Create CSV for Population

# %%
# Retreive all rows where WEO Subject Code is NGDPDPC for LP
population_df = weo_df[weo_df['WEO Subject Code'] == "LP"]
population_df.head()
# Out:
#      ISO WEO Subject Code              Country    2002    2003    2004  \
# 27   AFG               LP          Afghanistan  18.707  19.477  20.237
# 72   ALB               LP              Albania   3.051    3.04   3.027
# 117  DZA               LP              Algeria  31.414  31.885  32.366
# 162  AGO               LP               Angola  18.166  18.711  19.273
# 207  ATG               LP  Antigua and Barbuda   0.078   0.079   0.079
#
#        2005    2006    2007    2008    2009    2010    2011    2012    2013  \
# 27   20.947  21.596  22.426  22.997  23.596  24.269  25.031  25.864  26.736
# 72    3.011   2.993    2.97   2.947   2.928   2.913   2.905     2.9   2.895
# 117  32.855  33.351  33.858  34.591  35.268  35.978  36.717  37.495  38.297
# 162  19.851  20.446   21.06  21.692  22.342  23.013  23.703  24.414  25.147
# 207    0.08   0.081   0.082   0.083   0.084   0.085   0.086   0.087   0.088
#
#        2014    2015    2016    2017    2018
# ...

# %%
# Save DF to CSV
gdp_df.to_csv('WEO_Population.csv',index = False)

# %% [markdown]
# # Create CSV for Unemployment Rate

# %%
# Retreive all rows where WEO Subject Code is NGDPDPC for LUR
unemployment_df = weo_df[weo_df['WEO Subject Code'] == "LUR"]
unemployment_df.head()
# Out:
#      ISO WEO Subject Code              Country    2002    2003    2004  \
# 25   AFG              LUR          Afghanistan     NaN     NaN     NaN
# 70   ALB              LUR              Albania  15.751      15    14.4
# 115  DZA              LUR              Algeria  25.664  23.716  17.656
# 160  AGO              LUR               Angola     NaN     NaN     NaN
# 205  ATG              LUR  Antigua and Barbuda     NaN     NaN     NaN
#
#        2005    2006    2007    2008    2009   2010   2011    2012   2013  \
# 25      NaN     NaN     NaN     NaN     NaN    NaN    NaN     NaN    NaN
# 70     14.1    13.8    13.4    13.1    13.8     14     14    13.4   15.9
# 115  15.265  12.512  13.793  11.343  10.167  9.961  9.971  10.969  9.829
# 160     NaN     NaN     NaN     NaN     NaN    NaN    NaN     NaN    NaN
# 205     NaN     NaN     NaN     NaN     NaN    NaN    NaN     NaN    NaN
#
#      2014    2015    2016    2017    2018
# 25    NaN     NaN     NaN     NaN     NaN
# ...

# %%
# Save DF to CSV
gdp_df.to_csv('WEO_Unemployment.csv', index = False)
