# %%
# Import Dependencies

import os
import pandas as pd
import numpy as np
# from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# %%
# Get unemployment data
unemployment_df = pd.read_csv(os.path.join("../../../Data", "WEO_Unemployment.csv"), index_col=["ISO"])
unemployment_df
# Out:
#     WEO Subject Code              Country    2002    2003    2004    2005  \
# ISO
# AFG              LUR          Afghanistan     NaN     NaN     NaN     NaN
# ALB              LUR              Albania  15.751  15.000  14.400  14.100
# DZA              LUR              Algeria  25.664  23.716  17.656  15.265
# AGO              LUR               Angola     NaN     NaN     NaN     NaN
# ATG              LUR  Antigua and Barbuda     NaN     NaN     NaN     NaN
# ..               ...                  ...     ...     ...     ...     ...
# VNM              LUR              Vietnam   6.010   5.780   5.600   5.310
# WBG              LUR   West Bank and Gaza  31.200  25.500  26.800  23.500
# YEM              LUR                Yemen     NaN     NaN     NaN     NaN
# ZMB              LUR               Zambia     NaN     NaN     NaN     NaN
# ZWE              LUR             Zimbabwe     NaN     NaN     NaN     NaN
#
#        2006    2007    2008    2009    2010    2011    2012    2013  2014  \
# ISO
# AFG     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN
# ALB  13.800  13.400  13.100  13.800  14.000  14.000  13.400  15.900  17.5
# DZA  12.512  13.793  11.343  10.167   9.961   9.971  10.969   9.829  10.6
# AGO     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN
# ATG     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN
# ..      ...     ...     ...     ...     ...     ...     ...     ...   ...
# VNM   4.820   4.640   2.380   2.900   2.880   2.220   1.960   2.180   2.1
# WBG  23.700  21.700  26.600  24.500  23.700  20.900  23.000  23.400  26.9
# YEM     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN
# ZMB     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN
# ZWE     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN
#
#        2015    2016    2017    2018
# ISO
# AFG     NaN     NaN     NaN     NaN
# ALB  17.100  15.200  13.700  12.300
# DZA  11.214  10.498  11.709  11.731
# AGO     NaN     NaN     NaN     NaN
# ATG     NaN     NaN     NaN     NaN
# ..      ...     ...     ...     ...
# VNM   2.330   2.300   2.240   2.190
# WBG  25.900  26.900  25.450  26.250
# YEM     NaN     NaN     NaN     NaN
# ZMB     NaN     NaN     NaN     NaN
# ZWE     NaN     NaN     NaN     NaN
#
# [195 rows x 19 columns]

# %%
# Eliminate unemployment data features we won't need
unemployment_df.drop(["WEO Subject Code", "Country"], axis=1, inplace=True)
unemployment_df
# Out:
#        2002    2003    2004    2005    2006    2007    2008    2009    2010  \
# ISO
# AFG     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ALB  15.751  15.000  14.400  14.100  13.800  13.400  13.100  13.800  14.000
# DZA  25.664  23.716  17.656  15.265  12.512  13.793  11.343  10.167   9.961
# AGO     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ATG     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# VNM   6.010   5.780   5.600   5.310   4.820   4.640   2.380   2.900   2.880
# WBG  31.200  25.500  26.800  23.500  23.700  21.700  26.600  24.500  23.700
# YEM     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ZMB     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ZWE     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#        2011    2012    2013  2014    2015    2016    2017    2018
# ISO
# AFG     NaN     NaN     NaN   NaN     NaN     NaN     NaN     NaN
# ALB  14.000  13.400  15.900  17.5  17.100  15.200  13.700  12.300
# DZA   9.971  10.969   9.829  10.6  11.214  10.498  11.709  11.731
# AGO     NaN     NaN     NaN   NaN     NaN     NaN     NaN     NaN
# ATG     NaN     NaN     NaN   NaN     NaN     NaN     NaN     NaN
# ..      ...     ...     ...   ...     ...     ...     ...     ...
# VNM   2.220   1.960   2.180   2.1   2.330   2.300   2.240   2.190
# WBG  20.900  23.000  23.400  26.9  25.900  26.900  25.450  26.250
# YEM     NaN     NaN     NaN   NaN     NaN     NaN     NaN     NaN
# ZMB     NaN     NaN     NaN   NaN     NaN     NaN     NaN     NaN
# ZWE     NaN     NaN     NaN   NaN     NaN     NaN     NaN     NaN
#
# [195 rows x 17 columns]

# %%
unemployment_df.loc['ALB', '2002']
# Out:
# 15.751

# %%
# Put average unemployment in to its own DataFrame
avg_ue = unemployment_df.mean(axis=1)
avg_ue

avg_ue_df = pd.DataFrame(avg_ue, index=unemployment_df.index, columns=['avg_ue'])
avg_ue_df
# Out:
#         avg_ue
# ISO
# AFG        NaN
# ALB  14.497118
# DZA  13.329294
# AGO        NaN
# ATG        NaN
# ..         ...
# VNM   3.402353
# WBG  25.052941
# YEM        NaN
# ZMB        NaN
# ZWE        NaN
#
# [195 rows x 1 columns]

# %%
# Get GDP data
gdp_df = pd.read_csv(os.path.join("../../../Data", "WEO_GDP.csv"), index_col=["ISO"])
gdp_df.head()
# Out:
#     WEO Subject Code              Country       2002       2003       2004  \
# ISO
# AFG          NGDPDPC          Afghanistan    233.433    233.755    254.259
# ALB          NGDPDPC              Albania   1425.130   1846.120   2373.580
# DZA          NGDPDPC              Algeria   1806.860   2128.390   2636.310
# AGO          NGDPDPC               Angola    841.420    951.969   1222.040
# ATG          NGDPDPC  Antigua and Barbuda  10482.010  10892.400  11581.320
#
#           2005       2006       2007       2008       2009      2010  \
# ISO
# AFG    294.396    320.674    381.502    447.746    511.374    631.49
# ALB   2673.770   2972.750   3595.050   4370.560   4114.090   4097.83
# DZA   3141.030   3508.960   3986.560   4943.500   3886.060   4480.72
# AGO   1862.420   2561.860   3099.090   4081.690   3146.800   3641.44
# ATG  12736.240  14262.100  15992.740  16510.080  14612.900  13564.68
#
#          2011       2012       2013       2014       2015       2016  \
# ISO
# AFG    714.70    784.611    754.402    747.622    711.337    616.234
# ALB   4439.89   4248.910   4415.600   4584.920   3953.610   4124.410
# DZA   5453.89   5575.650   5477.060   5466.330   4153.320   3918.940
# AGO   4716.25   5245.020   5436.520   5625.740   4354.920   3676.830
# ATG  13295.36  13811.080  13392.220  13951.990  14696.890  15556.010
#
#           2017       2018
# ISO
# AFG    636.693    582.323
# ALB   4542.760   5284.440
# DZA   4079.650   4118.740
# AGO   4303.690   3620.590
# ATG  15655.230  16860.960

# %%
# Eliminate GDP features we won't need
gdp_df.drop(["WEO Subject Code", "Country"], axis=1, inplace=True)
gdp_df
# Out:
#           2002       2003       2004       2005       2006       2007  \
# ISO
# AFG    233.433    233.755    254.259    294.396    320.674    381.502
# ALB   1425.130   1846.120   2373.580   2673.770   2972.750   3595.050
# DZA   1806.860   2128.390   2636.310   3141.030   3508.960   3986.560
# AGO    841.420    951.969   1222.040   1862.420   2561.860   3099.090
# ATG  10482.010  10892.400  11581.320  12736.240  14262.100  15992.740
# ..         ...        ...        ...        ...        ...        ...
# VNM    546.555    610.357    756.981    873.136    996.255   1152.300
# WBG   1102.500   1197.160   1350.910   1461.090   1480.700   1563.700
# YEM    560.031    597.771    682.148    797.704    881.648    971.326
# ZMB    376.468    429.010    530.540    691.554   1030.690   1103.690
# ZWE    922.878    822.472    806.898    764.632    677.881    646.558
#
#           2008       2009       2010      2011       2012       2013  \
# ISO
# AFG    447.746    511.374    631.490    714.70    784.611    754.402
# ALB   4370.560   4114.090   4097.830   4439.89   4248.910   4415.600
# DZA   4943.500   3886.060   4480.720   5453.89   5575.650   5477.060
# AGO   4081.690   3146.800   3641.440   4716.25   5245.020   5436.520
# ATG  16510.080  14612.900  13564.680  13295.36  13811.080  13392.220
# ..         ...        ...        ...       ...        ...        ...
# VNM   1446.770   1481.810   1628.520   1950.46   2197.610   2370.090
# WBG   1913.320   2061.560   2406.260   2711.92   2888.600   3122.990
# YEM   1171.170   1060.930   1266.790   1302.30   1367.720   1515.950
# ZMB   1365.930   1135.010   1456.050   1635.17   1724.630   1839.330
# ZWE    553.376    790.352    975.851   1131.84   1310.370   1421.550
#
#           2014       2015       2016       2017       2018
# ISO
# AFG    747.622    711.337    616.234    636.693    582.323
# ALB   4584.920   3953.610   4124.410   4542.760   5284.440
# DZA   5466.330   4153.320   3918.940   4079.650   4118.740
# AGO   5625.740   4354.920   3676.830   4303.690   3620.590
# ATG  13951.990  14696.890  15556.010  15655.230  16860.960
# ..         ...        ...        ...        ...        ...
# VNM   2566.910   2582.390   2720.190   2957.930   3211.460
# WBG   3158.600   3084.130   3325.850   3407.310   3353.230
# YEM   1574.250   1500.690   1061.840    891.888    762.136
# ZMB   1726.650   1310.460   1254.120   1500.960   1480.420
# ZWE   1415.030   1425.010   1409.450   1516.280   1440.590
#
# [195 rows x 17 columns]

# %%
# transpose_ue_df = unemployment_df.T
# transpose_ue_df.reset_index()
# transpose_ue_df.set_index(unemployment_df.columns)
# transpose_ue_df

# %%
trafficking_df = pd.read_csv(os.path.join("../../../Exports", "eda5b.csv"))
trafficking_df.head()
# Out:
#    yearOfRegistration       Datasource  gender citizenship  isForcedLabour  \
# 0                2012  Case Management  Female          LK               1
# 1                2012  Case Management  Female          LK               1
# 2                2012  Case Management  Female          LK               1
# 3                2012  Case Management  Female          LK               1
# 4                2012  Case Management  Female          LK               1
#
#   ControlCategory RecruiterCategory   ExploitType     Labor_Type ageCategories
# 0         Threats             Other  Forced Labor  Domestic Work     Age 30-38
# 1       Financial             Other  Forced Labor  Domestic Work     Age 30-38
# 2         Threats             Other  Forced Labor  Domestic Work     Age 30-38
# 3       Financial             Other  Forced Labor  Domestic Work     Age 30-38
# 4       Financial             Other  Forced Labor  Domestic Work     Age 30-38

# %%
trafficking_df.shape
# Out:
# (14299, 10)

# %%
countries_df = pd.read_csv(os.path.join("../../../Data", "countries.csv"))
countries_df.head()
# Out:
#      country_name country_iso2 country_iso3  country_un_code
# 0     Afghanistan           AF          AFG                4
# 1   Aland Islands           AX          ALA              248
# 2         Albania           AL          ALB                8
# 3         Algeria           DZ          DZA               12
# 4  American Samoa           AS          ASM               16

# %%
trafficking_merge_df1 = trafficking_df.merge(countries_df, how='left', left_on='citizenship', right_on='country_iso2')
trafficking_merge_df1
# Out:
#        yearOfRegistration       Datasource  gender citizenship  \
# 0                    2012  Case Management  Female          LK
# 1                    2012  Case Management  Female          LK
# 2                    2012  Case Management  Female          LK
# 3                    2012  Case Management  Female          LK
# 4                    2012  Case Management  Female          LK
# ...                   ...              ...     ...         ...
# 14294                2018          Hotline    Male          US
# 14295                2018          Hotline    Male          US
# 14296                2018          Hotline    Male          US
# 14297                2018          Hotline    Male          US
# 14298                2018          Hotline    Male          US
#
#        isForcedLabour ControlCategory RecruiterCategory          ExploitType  \
# 0                   1         Threats             Other         Forced Labor
# 1                   1       Financial             Other         Forced Labor
# 2                   1         Threats             Other         Forced Labor
# 3                   1       Financial             Other         Forced Labor
# 4                   1       Financial             Other         Forced Labor
# ...               ...             ...               ...                  ...
# 14294               0         Threats   Family/Relative  Sexual Exploitation
# 14295               0         Threats   Family/Relative  Sexual Exploitation
# 14296               0         Threats   Family/Relative  Sexual Exploitation
# 14297               0           Other   Family/Relative  Sexual Exploitation
# 14298               0         Threats   Family/Relative  Sexual Exploitation
#
#           Labor_Type ageCategories              country_name country_iso2  \
# 0      Domestic Work     Age 30-38                 Sri Lanka           LK
# 1      Domestic Work     Age 30-38                 Sri Lanka           LK
# 2      Domestic Work     Age 30-38                 Sri Lanka           LK
# 3      Domestic Work     Age 30-38                 Sri Lanka           LK
# 4      Domestic Work     Age 30-38                 Sri Lanka           LK
# ...              ...           ...                       ...          ...
# 14294             12      Age 9-17  United States of America           US
# 14295             12      Age 9-17  United States of America           US
# 14296             12      Age 9-17  United States of America           US
# 14297             12      Age 9-17  United States of America           US
# 14298             12      Age 9-17  United States of America           US
#
#       country_iso3  country_un_code
# 0              LKA            144.0
# 1              LKA            144.0
# 2              LKA            144.0
# 3              LKA            144.0
# 4              LKA            144.0
# ...            ...              ...
# 14294          USA            840.0
# 14295          USA            840.0
# 14296          USA            840.0
# 14297          USA            840.0
# 14298          USA            840.0
#
# [14299 rows x 14 columns]

# %%
# x = trafficking_merge_df1.groupby(["country_iso3", "yearOfRegistration"]).agg(['count'])
x = trafficking_merge_df1.groupby(["country_iso3", "yearOfRegistration"]).size().reset_index(name="case_counts")

x
# Out:
#    country_iso3  yearOfRegistration  case_counts
# 0           AFG                2013            3
# 1           AFG                2014            1
# 2           BLR                2015           90
# 3           BLR                2016          112
# 4           BLR                2017           30
# 5           CHN                2017           11
# 6           CHN                2018           12
# 7           ERI                2014            1
# 8           HTI                2012           89
# 9           IDN                2014            1
# 10          IDN                2015            6
# 11          IDN                2016           28
# 12          IDN                2017           34
# 13          KEN                2017           29
# 14          KGZ                2014           71
# 15          KGZ                2015           66
# 16          KGZ                2016           20
# 17          KHM                2015           20
# 18          KHM                2016           31
# 19          KHM                2017           74
# 20          KHM                2018           14
# 21          KOR                2016           12
# 22          LKA                2012           31
# 23          LKA                2013           42
# 24          MEX                2017           19
# 25          MMR                2013           20
# 26          MMR                2014            3
# 27          MMR                2015          102
# 28          MMR                2016           35
# 29          MMR                2018           26
# 30          NGA                2015           98
# 31          NPL                2015           27
# 32          PHL                2015           25
# 33          PHL                2016           13
# 34          THA                2016           53
# 35          UGA                2014           66
# 36          UKR                2013          172
# 37          UKR                2014           69
# 38          UKR                2015          332
# 39          UKR                2016          320
# 40          UKR                2017          123
# 41          USA                2015          631
# 42          USA                2016         1227
# 43          USA                2017         1064
# 44          USA                2018          668
# 45          UZB                2015           10
# 46          UZB                2017           15

# %%
year_unemployment = []
year_gdp = []
for row in x.iterrows():
    year_unemployment.append(unemployment_df.loc[row[1]['country_iso3'], str(row[1]['yearOfRegistration'])])
    year_gdp.append(gdp_df.loc[row[1]['country_iso3'], str(row[1]['yearOfRegistration'])])

# %%
x['Unemployment'] = year_unemployment
x['GDP'] = year_gdp
x_no_null = x.dropna()
x_no_null
# Out:
#    country_iso3  yearOfRegistration  case_counts  Unemployment       GDP
# 2           BLR                2015           90         5.821   5941.24
# 3           BLR                2016          112         5.920   5022.47
# 4           BLR                2017           30         5.684   5757.29
# 5           CHN                2017           11         3.900   8823.46
# 6           CHN                2018           12         3.800   9919.81
# 9           IDN                2014            1         5.940   3533.61
# 10          IDN                2015            6         6.180   3367.69
# 11          IDN                2016           28         5.610   3605.72
# 12          IDN                2017           34         5.500   3885.47
# 14          KGZ                2014           71         8.046   1292.62
# 15          KGZ                2015           66         7.554   1132.84
# 16          KGZ                2016           20         7.211   1131.84
# 21          KOR                2016           12         3.675  29274.23
# 22          LKA                2012           31         4.000   3347.89
# 23          LKA                2013           42         4.400   3607.15
# 24          MEX                2017           19         3.423   9342.92
# 30          NGA                2015           98         9.000   2718.59
# 32          PHL                2015           25         6.275   3039.23
# 33          PHL                2016           13         5.475   3107.65
# 34          THA                2016           53         1.000   5995.21
# 36          UKR                2013          172         7.172   3968.80
# 37          UKR                2014           69         9.275   3053.61
# 38          UKR                2015          332         9.143   2124.62
# 39          UKR                2016          320         9.450   2200.00
# 40          UKR                2017          123         9.650   2655.94
# 41          USA                2015          631         5.275  56848.51
# 42          USA                2016         1227         4.875  58017.23
# 43          USA                2017         1064         4.350  60105.85
# 44          USA                2018          668         3.892  63055.98

# %%
# Drop country as a feature since we're looking for an overall model
# See if dropping year helps the model accuracy
x_no_null.drop(columns=["country_iso3", "yearOfRegistration"], axis=1, inplace=True)
x_no_null
# Out:
# C:\Users\mrm\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#     case_counts  Unemployment       GDP
# 2            90         5.821   5941.24
# 3           112         5.920   5022.47
# 4            30         5.684   5757.29
# 5            11         3.900   8823.46
# 6            12         3.800   9919.81
# 9             1         5.940   3533.61
# 10            6         6.180   3367.69
# 11           28         5.610   3605.72
# 12           34         5.500   3885.47
# 14           71         8.046   1292.62
# 15           66         7.554   1132.84
# 16           20         7.211   1131.84
# 21           12         3.675  29274.23
# 22           31         4.000   3347.89
# 23           42         4.400   3607.15
# 24           19         3.423   9342.92
# 30           98         9.000   2718.59
# 32           25         6.275   3039.23
# 33           13         5.475   3107.65
# 34           53         1.000   5995.21
# 36          172         7.172   3968.80
# 37           69         9.275   3053.61
# 38          332         9.143   2124.62
# 39          320         9.450   2200.00
# 40          123         9.650   2655.94
# 41          631         5.275  56848.51
# 42         1227         4.875  58017.23
# 43         1064         4.350  60105.85
# 44          668         3.892  63055.98

# %%
# Need to scale after splitting since we've got figures from the teens up to tens of thousands
outcomes = x_no_null["case_counts"]
data = x_no_null.drop(columns=["case_counts"])

# Create training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data, outcomes, random_state=52)

# Scale
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Run linear regression model
Regular = LinearRegression()

Regular.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_predictions = Regular.predict(X_test_scaled)
y_predictions
# Out:
# array([107.10758487,  70.80455867,  57.41802588,  88.04512831,
#        770.42414586,  56.83443423, 347.33690249,  89.54677203])

# %%
y_test
# Out:
# 36     172
# 24      19
# 12      34
# 4       30
# 42    1227
# 11      28
# 21      12
# 6       12
# Name: case_counts, dtype: int64
