# %% [markdown]
# ## Question
# If the victim of human trafficking is being forced to perform labor, can we predict the type of labor given the inputs available from our dataset?
#
# ### Data
# The base dataset includes features for:
#
# * Year
# * Data Source
# * Gender
# * Citizenship
# * Victim Forced to Labor
# * Type of Control Exerted Upon Victim
# * RecruiterCategory
# * ExploitType
# * LaborType
# * Age Categories
#
# *Not all of these features will be used in the model we create to predict the answers to our question.*
#
# ### Model
# Given an input set, we are trying to predict an outcome. In our base set, we have a known outcome (the type of labor forced upon the victim (represented by the 'Labor_Type' feature)). Can we use a supervised machine learning model with multi-class logistic regression to predict the specific type of labor being forced upon the victim?
#
# ### Output
# We need the model to predict one of 12 different forced labor categories derived from our data and ETL process.
#
# #### Table: Forced Labor Types Categorized

# %%
# Import Dependencies

import os
import pandas as pd
import numpy as np

from sqlalchemy import create_engine
from config import conn

from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
data_df = pd.read_sql_table("Trafficking_Cleaned", conn)
data_df
# Out:
#        yearOfRegistration       Datasource  gender citizenship  \
# 0                    2012  Case Management  Female          LK
# 1                    2012  Case Management  Female          LK
# 2                    2012  Case Management  Female          LK
# 3                    2012  Case Management  Female          LK
# 4                    2012  Case Management  Female          LK
# ...                   ...              ...     ...         ...
# 14294                2018          Hotline    Male          US
# 14295                2018          Hotline    Male          US
# 14296                2018          Hotline    Male          US
# 14297                2018          Hotline    Male          US
# 14298                2018          Hotline    Male          US
#
#        isForcedLabour ControlCategory RecruiterCategory          ExploitType  \
# 0                   1         Threats             Other         Forced Labor
# 1                   1       Financial             Other         Forced Labor
# 2                   1         Threats             Other         Forced Labor
# 3                   1       Financial             Other         Forced Labor
# 4                   1       Financial             Other         Forced Labor
# ...               ...             ...               ...                  ...
# 14294               0         Threats   Family/Relative  Sexual Exploitation
# 14295               0         Threats   Family/Relative  Sexual Exploitation
# 14296               0         Threats   Family/Relative  Sexual Exploitation
# 14297               0           Other   Family/Relative  Sexual Exploitation
# 14298               0         Threats   Family/Relative  Sexual Exploitation
#
#           Labor_Type ageCategories
# 0      Domestic Work     Age 30-38
# 1      Domestic Work     Age 30-38
# 2      Domestic Work     Age 30-38
# 3      Domestic Work     Age 30-38
# 4      Domestic Work     Age 30-38
# ...              ...           ...
# 14294        Unknown      Age 9-17
# 14295        Unknown      Age 9-17
# 14296        Unknown      Age 9-17
# 14297        Unknown      Age 9-17
# 14298        Unknown      Age 9-17
#
# [14299 rows x 10 columns]

# %%
# Subset our data looking at only instances of forced labor
forced_labor_df = data_df[data_df['isForcedLabour'] == 1]
forced_labor_df
# Out:
#        yearOfRegistration       Datasource  gender citizenship  \
# 0                    2012  Case Management  Female          LK
# 1                    2012  Case Management  Female          LK
# 2                    2012  Case Management  Female          LK
# 3                    2012  Case Management  Female          LK
# 4                    2012  Case Management  Female          LK
# ...                   ...              ...     ...         ...
# 14279                2018          Hotline    Male           0
# 14280                2018          Hotline    Male           0
# 14281                2018          Hotline    Male           0
# 14282                2018          Hotline    Male           0
# 14283                2018          Hotline    Male           0
#
#        isForcedLabour ControlCategory RecruiterCategory   ExploitType  \
# 0                   1         Threats             Other  Forced Labor
# 1                   1       Financial             Other  Forced Labor
# 2                   1         Threats             Other  Forced Labor
# 3                   1       Financial             Other  Forced Labor
# 4                   1       Financial             Other  Forced Labor
# ...               ...             ...               ...           ...
# 14279               1           Other     Not Specified  Forced Labor
# 14280               1           Other     Not Specified  Forced Labor
# 14281               1       Financial     Not Specified  Forced Labor
# 14282               1       Financial     Not Specified  Forced Labor
# 14283               1       Financial     Not Specified  Forced Labor
#
#           Labor_Type ageCategories
# 0      Domestic Work     Age 30-38
# 1      Domestic Work     Age 30-38
# 2      Domestic Work     Age 30-38
# 3      Domestic Work     Age 30-38
# 4      Domestic Work     Age 30-38
# ...              ...           ...
# 14279       Peddling      Age 9-17
# 14280       Peddling      Age 9-17
# 14281       Peddling      Age 9-17
# 14282       Peddling      Age 9-17
# 14283       Peddling      Age 9-17
#
# [2315 rows x 10 columns]

# %%
# A little EDA
forced_labor_df['Labor_Type'].value_counts()
# Out:
# Construction     810
# Unknown          563
# Manufacturing    304
# Domestic Work    229
# Other            103
# Aquafarming       91
# Begging           88
# Agriculture       69
# Peddling          58
# Name: Labor_Type, dtype: int64

# %%
# Drop features/columns that we won't want to initially include in our analysis/model
forced_labor_df.drop(["yearOfRegistration", "ExploitType", "Datasource", "isForcedLabour"], axis=1, inplace=True)
forced_labor_df
# Out:
# C:\Users\mrm\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#        gender citizenship ControlCategory RecruiterCategory     Labor_Type  \
# 0      Female          LK         Threats             Other  Domestic Work
# 1      Female          LK       Financial             Other  Domestic Work
# 2      Female          LK         Threats             Other  Domestic Work
# 3      Female          LK       Financial             Other  Domestic Work
# 4      Female          LK       Financial             Other  Domestic Work
# ...       ...         ...             ...               ...            ...
# 14279    Male           0           Other     Not Specified       Peddling
# 14280    Male           0           Other     Not Specified       Peddling
# 14281    Male           0       Financial     Not Specified       Peddling
# 14282    Male           0       Financial     Not Specified       Peddling
# 14283    Male           0       Financial     Not Specified       Peddling
#
#       ageCategories
# 0         Age 30-38
# 1         Age 30-38
# 2         Age 30-38
# 3         Age 30-38
# 4         Age 30-38
# ...             ...
# 14279      Age 9-17
# 14280      Age 9-17
# 14281      Age 9-17
# 14282      Age 9-17
# 14283      Age 9-17
#
# [2315 rows x 6 columns]

# %%
# Change 0 to null so rows can be dropped
forced_labor_df['citizenship'].replace({'0': np.nan}, inplace=True)
forced_labor_df['citizenship'].value_counts()
# Out:
# C:\Users\mrm\anaconda3\envs\mlenv\lib\site-packages\pandas\core\series.py:4515: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# UA    1016
# BY     222
# MM     186
# KG     157
# HT      89
# LK      73
# ID      69
# UG      66
# KH      64
# TH      53
# PH      38
# KE      29
# NP      27
# UZ      25
# MX      19
# AF       4
# Name: citizenship, dtype: int64

# %%
# Drop rows with null values
forced_labor_df.dropna(inplace=True)
forced_labor_df
# Out:
# C:\Users\mrm\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        gender citizenship ControlCategory    RecruiterCategory     Labor_Type  \
# 0      Female          LK         Threats                Other  Domestic Work
# 1      Female          LK       Financial                Other  Domestic Work
# 2      Female          LK         Threats                Other  Domestic Work
# 3      Female          LK       Financial                Other  Domestic Work
# 4      Female          LK       Financial                Other  Domestic Work
# ...       ...         ...             ...                  ...            ...
# 10380  Female          MM         Threats  Friend/Acquaintance        Unknown
# 10381  Female          MM         Threats  Friend/Acquaintance        Unknown
# 10382  Female          MM         Threats                Other        Unknown
# 10383  Female          MM         Threats  Friend/Acquaintance        Unknown
# 10384  Female          MM         Threats  Friend/Acquaintance        Unknown
#
#       ageCategories
# 0         Age 30-38
# 1         Age 30-38
# 2         Age 30-38
# 3         Age 30-38
# 4         Age 30-38
# ...             ...
# 10380      Age 9-17
# 10381      Age 9-17
# 10382      Age 9-17
# 10383      Age 9-17
# 10384      Age 9-17
#
# [2137 rows x 6 columns]

# %%
# Gender transformation
gender_transform = {
    "Male": 0, 
    "Female": 1
}

# Encode labeled data so the model can interpret it correctly
forced_labor_df['gender'] = forced_labor_df['gender'].apply(lambda x: gender_transform[x])
forced_labor_df
# Out:
# C:\Users\mrm\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        gender citizenship ControlCategory    RecruiterCategory     Labor_Type  \
# 0           1          LK         Threats                Other  Domestic Work
# 1           1          LK       Financial                Other  Domestic Work
# 2           1          LK         Threats                Other  Domestic Work
# 3           1          LK       Financial                Other  Domestic Work
# 4           1          LK       Financial                Other  Domestic Work
# ...       ...         ...             ...                  ...            ...
# 10380       1          MM         Threats  Friend/Acquaintance        Unknown
# 10381       1          MM         Threats  Friend/Acquaintance        Unknown
# 10382       1          MM         Threats                Other        Unknown
# 10383       1          MM         Threats  Friend/Acquaintance        Unknown
# 10384       1          MM         Threats  Friend/Acquaintance        Unknown
#
#       ageCategories
# 0         Age 30-38
# 1         Age 30-38
# 2         Age 30-38
# 3         Age 30-38
# 4         Age 30-38
# ...             ...
# 10380      Age 9-17
# 10381      Age 9-17
# 10382      Age 9-17
# 10383      Age 9-17
# 10384      Age 9-17
#
# [2137 rows x 6 columns]

# %%
# Country transformation
country_transform = {
    "US": 840, 
    "UA": 804,
    "BY": 112, 
    "MM": 104, 
    "KG": 417, 
    "KH": 116, 
    "NG": 566,
    "HT": 332,  
    "LK": 144, 
    "ID": 360, 
    "UG": 800, 
    "TH": 764, 
    "PH": 608,
    "KE": 404, 
    "NP": 524, 
    "UZ": 860, 
    "CN": 156, 
    "MX": 484, 
    "KR": 410, 
    "AF": 4, 
    "ER": 232
}

# Encode labeled data so the model can interpret it correctly
forced_labor_df['citizenship'] = forced_labor_df['citizenship'].apply(lambda x: country_transform[x])
forced_labor_df
# Out:
# C:\Users\mrm\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        gender  citizenship ControlCategory    RecruiterCategory  \
# 0           1          144         Threats                Other
# 1           1          144       Financial                Other
# 2           1          144         Threats                Other
# 3           1          144       Financial                Other
# 4           1          144       Financial                Other
# ...       ...          ...             ...                  ...
# 10380       1          104         Threats  Friend/Acquaintance
# 10381       1          104         Threats  Friend/Acquaintance
# 10382       1          104         Threats                Other
# 10383       1          104         Threats  Friend/Acquaintance
# 10384       1          104         Threats  Friend/Acquaintance
#
#           Labor_Type ageCategories
# 0      Domestic Work     Age 30-38
# 1      Domestic Work     Age 30-38
# 2      Domestic Work     Age 30-38
# 3      Domestic Work     Age 30-38
# 4      Domestic Work     Age 30-38
# ...              ...           ...
# 10380        Unknown      Age 9-17
# 10381        Unknown      Age 9-17
# 10382        Unknown      Age 9-17
# 10383        Unknown      Age 9-17
# 10384        Unknown      Age 9-17
#
# [2137 rows x 6 columns]

# %%
# Transform the ControlCategory
control_transform = {
    "Financial": 1, 
    "Threats": 2, 
    "Survival": 3, 
    "Physical": 4, 
    "Other": 5
}

# Encode data so the model can interpret it correctly
forced_labor_df['ControlCategory'] = forced_labor_df['ControlCategory'].apply(lambda x: control_transform[x])
forced_labor_df
# Out:
# C:\Users\mrm\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#        gender  citizenship  ControlCategory    RecruiterCategory  \
# 0           1          144                2                Other
# 1           1          144                1                Other
# 2           1          144                2                Other
# 3           1          144                1                Other
# 4           1          144                1                Other
# ...       ...          ...              ...                  ...
# 10380       1          104                2  Friend/Acquaintance
# 10381       1          104                2  Friend/Acquaintance
# 10382       1          104                2                Other
# 10383       1          104                2  Friend/Acquaintance
# 10384       1          104                2  Friend/Acquaintance
#
#           Labor_Type ageCategories
# 0      Domestic Work     Age 30-38
# 1      Domestic Work     Age 30-38
# 2      Domestic Work     Age 30-38
# 3      Domestic Work     Age 30-38
# 4      Domestic Work     Age 30-38
# ...              ...           ...
# 10380        Unknown      Age 9-17
# 10381        Unknown      Age 9-17
# 10382        Unknown      Age 9-17
# 10383        Unknown      Age 9-17
# 10384        Unknown      Age 9-17
#
# [2137 rows x 6 columns]

# %%
# Transform the Recruiter Category
recruiter_transform = {
    "Not Specified": 1, 
    "Other": 2, 
    "Friend/Acquaintance": 3, 
    "Family/Relative": 4, 
    "Intimate Partner": 5
}

# Encode data so the model can interpret it correctly
forced_labor_df['RecruiterCategory'] = forced_labor_df['RecruiterCategory'].apply(lambda x: recruiter_transform[x])
forced_labor_df
# Out:
# C:\Users\mrm\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#        gender  citizenship  ControlCategory  RecruiterCategory     Labor_Type  \
# 0           1          144                2                  2  Domestic Work
# 1           1          144                1                  2  Domestic Work
# 2           1          144                2                  2  Domestic Work
# 3           1          144                1                  2  Domestic Work
# 4           1          144                1                  2  Domestic Work
# ...       ...          ...              ...                ...            ...
# 10380       1          104                2                  3        Unknown
# 10381       1          104                2                  3        Unknown
# 10382       1          104                2                  2        Unknown
# 10383       1          104                2                  3        Unknown
# 10384       1          104                2                  3        Unknown
#
#       ageCategories
# 0         Age 30-38
# 1         Age 30-38
# 2         Age 30-38
# 3         Age 30-38
# 4         Age 30-38
# ...             ...
# 10380      Age 9-17
# 10381      Age 9-17
# 10382      Age 9-17
# 10383      Age 9-17
# 10384      Age 9-17
#
# [2137 rows x 6 columns]

# %%
# Transform the Labor Type
labor_transform = {
    "Domestic Work": 1, 
    "Other": 2, 
    "Unknown": 3, 
    "Agriculture": 4, 
    "Manufacturing": 5, 
    "Construction": 6, 
    "Begging": 7, 
    "Aquafarming": 8
}

# Encode data so the model can interpret it correctly
forced_labor_df['Labor_Type'] = forced_labor_df['Labor_Type'].apply(lambda x: labor_transform[x])
forced_labor_df
# Out:
# C:\Users\mrm\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        gender  citizenship  ControlCategory  RecruiterCategory  Labor_Type  \
# 0           1          144                2                  2           1
# 1           1          144                1                  2           1
# 2           1          144                2                  2           1
# 3           1          144                1                  2           1
# 4           1          144                1                  2           1
# ...       ...          ...              ...                ...         ...
# 10380       1          104                2                  3           3
# 10381       1          104                2                  3           3
# 10382       1          104                2                  2           3
# 10383       1          104                2                  3           3
# 10384       1          104                2                  3           3
#
#       ageCategories
# 0         Age 30-38
# 1         Age 30-38
# 2         Age 30-38
# 3         Age 30-38
# 4         Age 30-38
# ...             ...
# 10380      Age 9-17
# 10381      Age 9-17
# 10382      Age 9-17
# 10383      Age 9-17
# 10384      Age 9-17
#
# [2137 rows x 6 columns]

# %%
# Transform Age Categories
age_transform = {
    "Age 0-8": 1, 
    "Age 9-17": 2, 
    "Age 18-20": 3, 
    "Age 21-23": 4, 
    "Age 24-26": 5, 
    "Age 27-29": 6, 
    "Age 30-38": 7, 
    "Age 39-47": 8, 
    "Age 48+": 9
}

# Encode data so the model can interpret it correctly
forced_labor_df['ageCategories'] = forced_labor_df['ageCategories'].apply(lambda x: age_transform[x])
forced_labor_df
# Out:
# C:\Users\mrm\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#        gender  citizenship  ControlCategory  RecruiterCategory  Labor_Type  \
# 0           1          144                2                  2           1
# 1           1          144                1                  2           1
# 2           1          144                2                  2           1
# 3           1          144                1                  2           1
# 4           1          144                1                  2           1
# ...       ...          ...              ...                ...         ...
# 10380       1          104                2                  3           3
# 10381       1          104                2                  3           3
# 10382       1          104                2                  2           3
# 10383       1          104                2                  3           3
# 10384       1          104                2                  3           3
#
#        ageCategories
# 0                  7
# 1                  7
# 2                  7
# 3                  7
# 4                  7
# ...              ...
# 10380              2
# 10381              2
# 10382              2
# 10383              2
# 10384              2
#
# [2137 rows x 6 columns]

# %%
# Separate our data from our outcomes
y = forced_labor_df['Labor_Type']
X = forced_labor_df.drop(['Labor_Type'], axis=1)
data_df.head()

# Split data in to train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y,  random_state=1, stratify=y)

# %%
# Create a pipeline and scale the input
labor_model = make_pipeline(StandardScaler(), SGDClassifier(max_iter=500, tol=1e-3))
labor_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('sgdclassifier', SGDClassifier(max_iter=500))])

# %%
# Compare our model's predictions to our known outcomes
y_pred = labor_model.predict(X_test)

# Create a DataFrame if we need to take a deeper dive
# results = pd.DataFrame({"Prediction": y_pred, "Actual": y_test}).reset_index(drop=True)
# results

# %%
# Check accuracy
accuracy_score(y_test, y_pred)
# Out:
# 0.6747663551401869

# %%
# Check performance
confusion_matrix(y_test, y_pred)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.68      0.96      0.80        57
#            2       0.00      0.00      0.00         1
#            3       0.86      0.35      0.49       141
#            4       0.00      0.00      0.00        17
#            5       0.71      0.54      0.61        76
#            6       0.63      0.97      0.76       203
#            7       1.00      1.00      1.00        17
#            8       0.33      0.09      0.14        23
#
#     accuracy                           0.67       535
#    macro avg       0.53      0.49      0.48       535
# weighted avg       0.68      0.67      0.63       535
# C:\Users\mrm\anaconda3\envs\mlenv\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mrm\anaconda3\envs\mlenv\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mrm\anaconda3\envs\mlenv\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
