# %%
import os
import pandas as pd

# %%
# Import World Bank poverty data
# https://data.worldbank.org/indicator/SI.POV.NAHC?view=map&year_high_desc=true

poverty_df = pd.read_csv("API_SI.POV.NAHC_DS2_en_csv_v2_2917413.csv")
poverty_df.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name Indicator Code  1960  \
# 0  Poverty headcount ratio at national poverty li...    SI.POV.NAHC   NaN
# 1  Poverty headcount ratio at national poverty li...    SI.POV.NAHC   NaN
# 2  Poverty headcount ratio at national poverty li...    SI.POV.NAHC   NaN
# 3  Poverty headcount ratio at national poverty li...    SI.POV.NAHC   NaN
# 4  Poverty headcount ratio at national poverty li...    SI.POV.NAHC   NaN
#
#    1961  1962  1963  1964  1965  ...  2011  2012  2013  2014  2015  2016  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
# Drop unnecessary columns
poverty_df.drop(["Indicator Name",
            "1960", "1961", "1962", "1963", "1964", "1965", "1966", "1967", "1968", "1969", 
            "1970", "1971", "1972", "1973", "1974", "1975", "1976", "1977", "1978", "1979", 
            "1980", "1981", "1982", "1983", "1984", "1985", "1986", "1987", "1988", "1989",
            "1990", "1991", "1992", "1993", "1994", "1995", "1996", "1997", "1998", "1999", 
            "2000", "2001", "2019", "2020"
            ], axis=1, inplace=True)
poverty_df.head()
# Out:
#                   Country Name Country Code Indicator Code  2002  2003  2004  \
# 0                        Aruba          ABW    SI.POV.NAHC   NaN   NaN   NaN
# 1  Africa Eastern and Southern          AFE    SI.POV.NAHC   NaN   NaN   NaN
# 2                  Afghanistan          AFG    SI.POV.NAHC   NaN   NaN   NaN
# 3   Africa Western and Central          AFW    SI.POV.NAHC   NaN   NaN   NaN
# 4                       Angola          AGO    SI.POV.NAHC   NaN   NaN   NaN
#
#    2005  2006  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN  33.7   NaN   NaN   NaN  38.3   NaN   NaN   NaN   NaN  54.5
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2017  2018
# 0   NaN   NaN
# 1   NaN   NaN
# ...

# %%
poverty_df = poverty_df[['Country Code', 'Indicator Code','Country Name', '2002', '2003', '2004', '2005', '2006', '2007',
                        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']]
poverty_df.head(20)
# Out:
#    Country Code Indicator Code                 Country Name  2002  2003  2004  \
# 0           ABW    SI.POV.NAHC                        Aruba   NaN   NaN   NaN
# 1           AFE    SI.POV.NAHC  Africa Eastern and Southern   NaN   NaN   NaN
# 2           AFG    SI.POV.NAHC                  Afghanistan   NaN   NaN   NaN
# 3           AFW    SI.POV.NAHC   Africa Western and Central   NaN   NaN   NaN
# 4           AGO    SI.POV.NAHC                       Angola   NaN   NaN   NaN
# 5           ALB    SI.POV.NAHC                      Albania  25.4   NaN   NaN
# 6           AND    SI.POV.NAHC                      Andorra   NaN   NaN   NaN
# 7           ARB    SI.POV.NAHC                   Arab World   NaN   NaN   NaN
# 8           ARE    SI.POV.NAHC         United Arab Emirates   NaN   NaN   NaN
# 9           ARG    SI.POV.NAHC                    Argentina   NaN   NaN   NaN
# 10          ARM    SI.POV.NAHC                      Armenia   NaN   NaN   NaN
# ...

# %%
# Save DF to CSV
poverty_df.to_csv('WorldBank_Poverty.csv', index = False)
