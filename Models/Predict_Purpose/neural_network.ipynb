# %% [markdown]
# ### Question
# Does the victim's age, gender, relationship to trafficker, and citizenship predict the victim's purpose?
#
# #### Model
# Given an input set, we are trying to predict an outcome. In our base set, we have a known outcome (the victim's purpose, which is mostly known from the case data). Can we use an unsupervised machine learning model or a neural-network learning model to predict the type of exploit?
#
# #### Output
# We need the model to predict one of six different exploit categories derived from our data and ETL process.
#
# ### Table: Exploit Types Categorized
# | Original Data | Data Code |
# | ----- | ----- |
# | Sexual exploitation | 1 |
# | Forced labour | 2 |
# | Other/Multiple | 3 |
# | Slavery and similar practices | 4 |
# | Forced marriage | 5 |
# | -99 (Unknown) | NaN |

# %%
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import numpy as np

# %%
nn_model_df = pd.read_csv(os.path.join("../../Exports", "eda5.csv"))
nn_model_df.head()
# Out:
#    yearOfRegistration  Datasource  gender  citizenship  isForcedLabour  \
# 0                2012           1       1           27               1
# 1                2012           1       1           27               1
# 2                2012           1       1           27               1
# 3                2012           1       1           27               1
# 4                2012           1       1           27               1
#
#    ControlCategory  RecruiterCategory  ExploitType  Labor_Type  ageCategories
# 0                2                  2            2           5              7
# 1                1                  2            2           5              7
# 2                2                  2            2           5              7
# 3                1                  2            2           5              7
# 4                1                  2            2           5              7

# %%
# Find any categorical data
# Categories
categories = nn_model_df.dtypes[nn_model_df.dtypes == "object"].index.tolist()
categories
# Out:
# []

# %%
# No categorical data, so we can skip OneHotEncoder and merging encoded data
# We won't bin more than we already have
# Create our splits for training and testing
y = nn_model_df["ExploitType"]
X = nn_model_df.drop(columns=["ExploitType"])

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 52)

# %%
# Define deep neural net model
input_feature_number = len(X_train["yearOfRegistration"])
hidden_nodes_layer1 = 100
hidden_nodes_layer2 = 50

nn = tf.keras.models.Sequential()

# 1st hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=9, input_shape=(9,), activation="relu"))

# 2nd hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="relu"))

# Summary check
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 100)               1000
# _________________________________________________________________
# dense_4 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 6,101
# Trainable params: 6,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Checkpoints
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames
os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/Project_Checkpoints.hdf5"

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_freq='epoch')

# Train the model
fit_model = nn.fit(X_train,y_train,epochs=50,callbacks=[cp_callback])
# Out:
# Epoch 1/50
# 140/140 [==============================] - 1s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00001: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 2/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00002: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 3/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00003: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 4/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00004: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 5/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00005: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 6/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00006: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 7/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00007: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 8/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00008: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 9/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00009: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 10/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00010: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 11/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00011: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 12/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9250 - accuracy: 0.0000e+00
#
# Epoch 00012: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 13/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00013: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 14/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00014: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 15/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00015: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 16/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00016: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 17/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00017: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 18/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00018: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 19/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00019: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 20/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00020: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 21/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00021: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 22/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00022: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 23/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00023: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 24/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00024: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 25/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00025: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 26/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00026: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 27/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00027: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 28/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00028: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 29/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00029: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 30/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00030: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 31/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00031: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 32/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00032: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 33/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00033: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 34/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00034: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 35/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00035: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 36/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00036: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 37/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00037: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 38/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00038: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 39/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00039: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 40/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00040: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 41/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00041: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 42/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00042: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 43/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00043: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 44/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00044: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 45/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00045: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 46/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00046: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 47/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00047: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 48/50
# 140/140 [==============================] - 0s 2ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00048: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 49/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00049: saving model to checkpoints\Project_Checkpoints.hdf5
# Epoch 50/50
# 140/140 [==============================] - 0s 1ms/step - loss: 21.9249 - accuracy: 0.0000e+00
#
# Epoch 00050: saving model to checkpoints\Project_Checkpoints.hdf5
